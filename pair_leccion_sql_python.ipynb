# %%
import mysql.connector
from mysql.connector import errorcode


import pandas as pd
import numpy as np

# %%
try:
  cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database = 'northwindmysql')
  print("Conexion establecida")

except mysql.connector.Error as err:

  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  
  else:
    print(err)
# Out:
# Conexion establecida

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database = 'information_schema')

mycursor = cnx.cursor()

try:
    consulta = "SELECT column_name FROM information_schema.columns WHERE table_schema = 'northwindmysql' and table_name = 'customers'"
    mycursor.execute(consulta)
    print(mycursor)
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
# Out:
# MySQLCursor: SELECT column_name FROM information_sche..

# %%
for x in mycursor:
    print(x[0])
# Out:
# customer_id
# company_name
# contact_name
# contact_title
# address
# city
# region
# postal_code
# country
# phone
# fax

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database = 'northwindmysql')

mycursor = cnx.cursor()

try:
    consulta = "SELECT * FROM customers WHERE country = 'USA' OR country = 'Germany'"
    mycursor.execute(consulta)
    resultado = mycursor.fetchall()

    for x in resultado:
        print(x)
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
# Out:
# ('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', '', '12209', 'Germany', '030-0074321', '030-0076545')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', '', '68306', 'Germany', '0621-08460', '0621-08924')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Order Administrator', 'Walserweg 21', 'Aachen', '', '52066', 'Germany', '0241-039123', '0241-059428')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Marketing Manager', 'Berliner Platz 43', 'M?nchen', '', '80805', 'Germany', '089-0877310', '089-0877451')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', '')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376')
# ...

# %%
df = pd.DataFrame(resultado, columns = ["customer_id", "company_name", "contact_name", "contact_title", "adrdress", "city", "región", "postal_code", "country", "phone", "fax"])
df.head(10)
# Out:
#   customer_id                company_name    contact_name  \
# 0       ALFKI         Alfreds Futterkiste    Maria Anders
# 1       BLAUS     Blauer See Delikatessen      Hanna Moos
# 2       DRACD    Drachenblut Delikatessen    Sven Ottlieb
# 3       FRANK              Frankenversand   Peter Franken
# 4       GREAL     Great Lakes Food Market   Howard Snyder
# 5       HUNGC  Hungry Coyote Import Store   Yoshi Latimer
# 6       KOENE             K?niglich Essen   Philip Cramer
# 7       LAZYK        Lazy K Kountry Store      John Steel
# 8       LEHMS         Lehmanns Marktstand  Renate Messner
# 9       LETSS           Let's Stop N Shop    Jaime Yorres
#
#           contact_title                        adrdress            city  \
# 0  Sales Representative                   Obere Str. 57          Berlin
# 1  Sales Representative                  Forsterstr. 57        Mannheim
# 2   Order Administrator                    Walserweg 21          Aachen
# ...

# %%
df.tail(10)
# Out:
#    customer_id                       company_name        contact_name  \
# 14       QUICK                         QUICK-Stop         Horst Kloss
# 15       RATTC         Rattlesnake Canyon Grocery        Paula Wilson
# 16       SAVEA                 Save-a-lot Markets      Jose Pavarotti
# 17       SPLIR              Split Rail Beer & Ale  Art Braunschweiger
# 18       THEBI                     The Big Cheese           Liz Nixon
# 19       THECR                    The Cracker Box            Liu Wong
# 20       TOMSP                 Toms Spezialit?ten       Karin Josephs
# 21       TRAIH  Trail's Head Gourmet Provisioners      Helvetius Nagy
# 22       WANDK                  Die Wandernde Kuh         Rita M?ller
# 23       WHITC               White Clover Markets      Karl Jablonski
#
#                      contact_title                     adrdress         city  \
# 14              Accounting Manager             Taucherstra?e 10    Cunewalde
# ...

# %%
df.sample(5)
# Out:
#    customer_id            company_name        contact_name  \
# 17       SPLIR   Split Rail Beer & Ale  Art Braunschweiger
# 14       QUICK              QUICK-Stop         Horst Kloss
# 19       THECR         The Cracker Box            Liu Wong
# 12       OLDWO  Old World Delicatessen       Rene Phillips
# 11       MORGK  Morgenstern Gesundkost     Alexander Feuer
#
#            contact_title             adrdress       city región postal_code  \
# 17         Sales Manager         P.O. Box 555     Lander     WY       82520
# 14    Accounting Manager     Taucherstra?e 10  Cunewalde              01307
# 19   Marketing Assistant  55 Grizzly Peak Rd.      Butte     MT       59801
# 12  Sales Representative      2743 Bering St.  Anchorage     AK       99508
# 11   Marketing Assistant          Heerstr. 22    Leipzig              04179
#
#     country           phone             fax
# 17      USA  (307) 555-4680  (307) 555-6525
# 14  Germany     0372-035188
# ...

# %%
df.isnull().sum()
# Out:
# customer_id      0
# company_name     0
# contact_name     0
# contact_title    0
# adrdress         0
# city             0
# región           0
# postal_code      0
# country          0
# phone            0
# fax              0
# dtype: int64

# %%
df.describe()
# Out:
#        customer_id         company_name  contact_name         contact_title  \
# count           24                   24            24                    24
# unique          24                   24            24                     9
# top          ALFKI  Alfreds Futterkiste  Maria Anders  Sales Representative
# freq             1                    1             1                     7
#
#              adrdress      city región postal_code country        phone fax
# count              24        24     24          24      24           24  24
# unique             24        23      9          24       2           24  18
# top     Obere Str. 57  Portland              12209     USA  030-0074321
# freq                1         2     11           1      13            1   7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    24 non-null     object
#  1   company_name   24 non-null     object
#  2   contact_name   24 non-null     object
#  3   contact_title  24 non-null     object
#  4   adrdress       24 non-null     object
#  5   city           24 non-null     object
#  6   región         24 non-null     object
#  7   postal_code    24 non-null     object
#  8   country        24 non-null     object
#  9   phone          24 non-null     object
#  10  fax            24 non-null     object
# dtypes: object(11)
# memory usage: 2.2+ KB

# %%
df.columns
# Out:
# Index(['customer_id', 'company_name', 'contact_name', 'contact_title',
#        'adrdress', 'city', 'región', 'postal_code', 'country', 'phone', 'fax'],
#       dtype='object')
